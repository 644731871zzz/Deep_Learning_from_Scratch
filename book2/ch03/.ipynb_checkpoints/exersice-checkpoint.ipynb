# %%
import numpy as np

# %%
c = np.array([1,0,0,0,0,0,0])
W = np.random.randn(7,3)
# Out:
# array([[ 1.44301986, -0.17607307,  2.06322121, -1.89863124, -0.15750639,
#         -0.82442908, -0.21326521],
#        [ 0.56692177,  0.89093756,  0.44900476,  0.47002435, -0.13124399,
#         -0.13350497,  1.70997102],
#        [-1.24741321,  1.07154758,  1.10009231,  1.19837967,  0.58768531,
#         -0.35865091,  0.36878198]])

# %%
h = np.dot(c,W.T)
print(h)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 h = np.dot(c,W.T)
#       2 print(h)
#
# ValueError: shapes (7,) and (3,7) not aligned: 7 (dim 0) != 3 (dim 0)
