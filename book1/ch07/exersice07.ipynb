# %%
import numpy as np

# %%
x = np.random.rand(10,1,28,28)#0-1均匀分布
x.shape
# Out:
# (10, 1, 28, 28)

# %%
x[0].shape
# Out:
# (1, 28, 28)

# %%
x[1].shape
# Out:
# (1, 28, 28)

# %%
x[0,0].shape
# Out:
# (28, 28)

# %%
x[0][0].shape
# Out:
# (28, 28)

# %%
import numpy as np
import sys, os
sys.path.append(os.pardir)
from common.util import im2col
# Out:
# (9, 75)

# %%
x1 = np.random.rand(1,3,7,7)
col1 = im2col(x1,5,5,stride = 1,pad = 0)
print(col1.shape)
# Out:
# (9, 75)

# %%
x2 = np.random.rand(10,3,7,7)
col2 = im2col(x2,5,5,stride = 1,pad = 0)
print(col2.shape)
# Out:
# (90, 75)
